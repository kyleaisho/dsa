# %%
from build_adj_list import build_from_tuple, print_graph

G = [[1, 2], [2,3], [3, 1]]

graph = build_from_tuple(G)
print_graph(graph)

# %%
from build_adj_list import build_from_tuple, print_graph

G = [[1, 2], [2,3], [3, 1]]

graph = build_from_tuple(G)
print_graph(graph, True)
